# %% [markdown]
# <a href="https://colab.research.google.com/github/venkatasl/AIML_TRAINING_VENKAT/blob/venkat_creation/insession_bias_summerschool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # What is bias?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Bias can mean many things
# * psychology -- systematic deviation from rationality in judgment
# * statistics -- systematic error in the collection, analysis, or interpretation of data
# * CS/ML -- systematic favoritism or discrimination towards certain groups or outcomes
#
# ### Let's pin down what we mean
#
# * When we say bias, we mean a stereotypical inclination to one entity over another
# * Gender bias, would therefore, be an association of some situation to a gender

# %% [markdown]
# # What we'll do today 😀
#
# * Create gender-biased data
# * Train a model on this bias data
# * Use CrowS-Pairs to measure model bias
# * Use AutoDebias to debias a model

# %% [markdown]
# # Get files ready

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf sample_data

# %%
# !cp drive/MyDrive/content.zip .

# %%
# !unzip content.zip
# Out:
# Archive:  content.zip
#    creating: Auto-Debias/
#   inflating: Auto-Debias/utils.py
#    creating: Auto-Debias/.git/
#  extracting: Auto-Debias/.git/HEAD
#   inflating: Auto-Debias/.git/config
#   inflating: Auto-Debias/.git/description
#    creating: Auto-Debias/.git/objects/
#    creating: Auto-Debias/.git/objects/info/
#    creating: Auto-Debias/.git/objects/pack/
#   inflating: Auto-Debias/.git/objects/pack/pack-0ec1d1d78a614bdd5b81297838b71e044fbafaf5.pack
#   inflating: Auto-Debias/.git/objects/pack/pack-0ec1d1d78a614bdd5b81297838b71e044fbafaf5.idx
#    creating: Auto-Debias/.git/info/
#   inflating: Auto-Debias/.git/info/exclude
#   inflating: Auto-Debias/.git/packed-refs
#    creating: Auto-Debias/.git/hooks/
#   inflating: Auto-Debias/.git/hooks/post-update.sample
#   inflating: Auto-Debias/.git/hooks/pre-merge-commit.sample
#   inflating: Auto-Debias/.git/hooks/applypatch-msg.sample
#   inflating: Auto-Debias/.git/hooks/prepare-commit-msg.sample
#   inflating: Auto-Debias/.git/hooks/push-to-checkout.sample
#   inflating: Auto-Debias/.git/hooks/pre-applypatch.sample
#   inflating: Auto-Debias/.git/hooks/pre-push.sample
#   inflating: Auto-Debias/.git/hooks/pre-commit.sample
#   inflating: Auto-Debias/.git/hooks/update.sample
#   inflating: Auto-Debias/.git/hooks/pre-rebase.sample
#   inflating: Auto-Debias/.git/hooks/pre-receive.sample
#   inflating: Auto-Debias/.git/hooks/commit-msg.sample
#   inflating: Auto-Debias/.git/hooks/fsmonitor-watchman.sample
#   inflating: Auto-Debias/.git/index
#    creating: Auto-Debias/.git/branches/
#    creating: Auto-Debias/.git/logs/
#   inflating: Auto-Debias/.git/logs/HEAD
#    creating: Auto-Debias/.git/logs/refs/
#    creating: Auto-Debias/.git/logs/refs/remotes/
#    creating: Auto-Debias/.git/logs/refs/remotes/origin/
#   inflating: Auto-Debias/.git/logs/refs/remotes/origin/HEAD
#    creating: Auto-Debias/.git/logs/refs/heads/
#   inflating: Auto-Debias/.git/logs/refs/heads/main
#    creating: Auto-Debias/.git/refs/
#    creating: Auto-Debias/.git/refs/remotes/
#    creating: Auto-Debias/.git/refs/remotes/origin/
#  extracting: Auto-Debias/.git/refs/remotes/origin/HEAD
#    creating: Auto-Debias/.git/refs/heads/
#   inflating: Auto-Debias/.git/refs/heads/main
#    creating: Auto-Debias/.git/refs/tags/
#    creating: Auto-Debias/__pycache__/
#   inflating: Auto-Debias/__pycache__/utils.cpython-310.pyc
#   inflating: Auto-Debias/README.md
#   inflating: Auto-Debias/auto-debias.py
#    creating: Auto-Debias/data/
#   inflating: Auto-Debias/data/prompts_bert-base-uncased_gender
#   inflating: Auto-Debias/data/male.txt
#   inflating: Auto-Debias/data/race2.txt
#   inflating: Auto-Debias/data/prompts_albert-base-v2_race
#   inflating: Auto-Debias/data/wiki_words_5000.txt
#   inflating: Auto-Debias/data/stereotype.txt
#   inflating: Auto-Debias/data/race1.txt
#   inflating: Auto-Debias/data/female.txt
#   inflating: Auto-Debias/generate_prompts.py
#    creating: biased-model/
#   inflating: biased-model/special_tokens_map.json
#   inflating: biased-model/config.json
#    creating: biased-model/1_Pooling/
#   inflating: biased-model/1_Pooling/config.json
#   inflating: biased-model/model.safetensors
#   inflating: biased-model/README.md
#   inflating: biased-model/tokenizer_config.json
#   inflating: biased-model/tokenizer.json
#    creating: biased-model/2_Normalize/
#   inflating: biased-model/sentence_bert_config.json
#   inflating: biased-model/vocab.txt
#   inflating: biased-model/config_sentence_transformers.json
#   inflating: biased-model/modules.json
#    creating: crows-pairs/
#    creating: crows-pairs/.git/
#  extracting: crows-pairs/.git/HEAD
#   inflating: crows-pairs/.git/config
#   inflating: crows-pairs/.git/description
#    creating: crows-pairs/.git/objects/
#    creating: crows-pairs/.git/objects/info/
#    creating: crows-pairs/.git/objects/pack/
#   inflating: crows-pairs/.git/objects/pack/pack-f222f8d86c2198c1983f6cac50f53e1fc30ae7f3.idx
#   inflating: crows-pairs/.git/objects/pack/pack-f222f8d86c2198c1983f6cac50f53e1fc30ae7f3.pack
#    creating: crows-pairs/.git/info/
#   inflating: crows-pairs/.git/info/exclude
#   inflating: crows-pairs/.git/packed-refs
#    creating: crows-pairs/.git/hooks/
#   inflating: crows-pairs/.git/hooks/post-update.sample
#   inflating: crows-pairs/.git/hooks/pre-merge-commit.sample
#   inflating: crows-pairs/.git/hooks/applypatch-msg.sample
#   inflating: crows-pairs/.git/hooks/prepare-commit-msg.sample
#   inflating: crows-pairs/.git/hooks/push-to-checkout.sample
#   inflating: crows-pairs/.git/hooks/pre-applypatch.sample
#   inflating: crows-pairs/.git/hooks/pre-push.sample
#   inflating: crows-pairs/.git/hooks/pre-commit.sample
#   inflating: crows-pairs/.git/hooks/update.sample
#   inflating: crows-pairs/.git/hooks/pre-rebase.sample
#   inflating: crows-pairs/.git/hooks/pre-receive.sample
#   inflating: crows-pairs/.git/hooks/commit-msg.sample
#   inflating: crows-pairs/.git/hooks/fsmonitor-watchman.sample
#   inflating: crows-pairs/.git/index
#    creating: crows-pairs/.git/branches/
#    creating: crows-pairs/.git/logs/
#   inflating: crows-pairs/.git/logs/HEAD
#    creating: crows-pairs/.git/logs/refs/
#    creating: crows-pairs/.git/logs/refs/remotes/
#    creating: crows-pairs/.git/logs/refs/remotes/origin/
#   inflating: crows-pairs/.git/logs/refs/remotes/origin/HEAD
#    creating: crows-pairs/.git/logs/refs/heads/
#   inflating: crows-pairs/.git/logs/refs/heads/master
#    creating: crows-pairs/.git/refs/
#    creating: crows-pairs/.git/refs/remotes/
#    creating: crows-pairs/.git/refs/remotes/origin/
#  extracting: crows-pairs/.git/refs/remotes/origin/HEAD
#    creating: crows-pairs/.git/refs/heads/
#   inflating: crows-pairs/.git/refs/heads/master
#    creating: crows-pairs/.git/refs/tags/
#    creating: crows-pairs/mturk/
#    creating: crows-pairs/mturk/_layouts/
#   inflating: crows-pairs/mturk/_layouts/validation.html
#   inflating: crows-pairs/mturk/_layouts/stereoset-validation.html
#    creating: crows-pairs/mturk/faq/
#   inflating: crows-pairs/mturk/faq/validation.md
#   inflating: crows-pairs/mturk/faq/faq.md
#   inflating: crows-pairs/mturk/faq/stereoset-validation.md
#    creating: crows-pairs/mturk/hit_layouts/
#   inflating: crows-pairs/mturk/hit_layouts/instructions.html
#   inflating: crows-pairs/mturk/hit_layouts/validationLayout.html
#   inflating: crows-pairs/mturk/hit_layouts/validationLayoutStereo.html
#   inflating: crows-pairs/metric.py
#   inflating: crows-pairs/README.md
#  extracting: crows-pairs/requirements.txt
#    creating: crows-pairs/data/
#   inflating: crows-pairs/data/crows_pairs_anonymized.csv
#   inflating: crows-pairs/data/prompts.csv
#   inflating: crows-pairs/data/README.md
#    creating: model/
#    creating: model/debiased_model_/
#    creating: model/debiased_model_/content/
#    creating: model/debiased_model_/content/biased-model_gender/
#   inflating: model/debiased_model_/content/biased-model_gender/special_tokens_map.json
#   inflating: model/debiased_model_/content/biased-model_gender/config.json
#   inflating: model/debiased_model_/content/biased-model_gender/model.safetensors
#   inflating: model/debiased_model_/content/biased-model_gender/tokenizer_config.json
#   inflating: model/debiased_model_/content/biased-model_gender/vocab.txt
#  extracting: model/content.zip
#   inflating: occupations.csv
#   inflating: professions.csv
#   inflating: requirements.txt
#   inflating: temp.txt
#    creating: winogender-schemas/
#    creating: winogender-schemas/.git/
#  extracting: winogender-schemas/.git/HEAD
#   inflating: winogender-schemas/.git/config
#   inflating: winogender-schemas/.git/description
#    creating: winogender-schemas/.git/objects/
#    creating: winogender-schemas/.git/objects/info/
#    creating: winogender-schemas/.git/objects/pack/
#   inflating: winogender-schemas/.git/objects/pack/pack-50476617c5939b4c2380aee9e5655772ed7fa149.idx
#   inflating: winogender-schemas/.git/objects/pack/pack-50476617c5939b4c2380aee9e5655772ed7fa149.pack
#    creating: winogender-schemas/.git/info/
#   inflating: winogender-schemas/.git/info/exclude
#   inflating: winogender-schemas/.git/packed-refs
#    creating: winogender-schemas/.git/hooks/
#   inflating: winogender-schemas/.git/hooks/post-update.sample
#   inflating: winogender-schemas/.git/hooks/pre-merge-commit.sample
#   inflating: winogender-schemas/.git/hooks/applypatch-msg.sample
#   inflating: winogender-schemas/.git/hooks/prepare-commit-msg.sample
#   inflating: winogender-schemas/.git/hooks/push-to-checkout.sample
#   inflating: winogender-schemas/.git/hooks/pre-applypatch.sample
#   inflating: winogender-schemas/.git/hooks/pre-push.sample
#   inflating: winogender-schemas/.git/hooks/pre-commit.sample
#   inflating: winogender-schemas/.git/hooks/update.sample
#   inflating: winogender-schemas/.git/hooks/pre-rebase.sample
#   inflating: winogender-schemas/.git/hooks/pre-receive.sample
#   inflating: winogender-schemas/.git/hooks/commit-msg.sample
#   inflating: winogender-schemas/.git/hooks/fsmonitor-watchman.sample
#   inflating: winogender-schemas/.git/index
#    creating: winogender-schemas/.git/branches/
#    creating: winogender-schemas/.git/logs/
#   inflating: winogender-schemas/.git/logs/HEAD
#    creating: winogender-schemas/.git/logs/refs/
#    creating: winogender-schemas/.git/logs/refs/remotes/
#    creating: winogender-schemas/.git/logs/refs/remotes/origin/
#   inflating: winogender-schemas/.git/logs/refs/remotes/origin/HEAD
#    creating: winogender-schemas/.git/logs/refs/heads/
#   inflating: winogender-schemas/.git/logs/refs/heads/master
#    creating: winogender-schemas/.git/refs/
#    creating: winogender-schemas/.git/refs/remotes/
#    creating: winogender-schemas/.git/refs/remotes/origin/
#  extracting: winogender-schemas/.git/refs/remotes/origin/HEAD
#    creating: winogender-schemas/.git/refs/heads/
#  extracting: winogender-schemas/.git/refs/heads/master
#    creating: winogender-schemas/.git/refs/tags/
#    creating: winogender-schemas/scripts/
#   inflating: winogender-schemas/scripts/instantiate.py
#    creating: winogender-schemas/paper/
#   inflating: winogender-schemas/paper/gender-bias-coreference.pdf
#   inflating: winogender-schemas/LICENSE
#   inflating: winogender-schemas/README.md
#    creating: winogender-schemas/data/
#   inflating: winogender-schemas/data/occupations-stats.tsv
#   inflating: winogender-schemas/data/all_sentences.tsv
#   inflating: winogender-schemas/data/templates.tsv

# %%
# !rm -rf __MACOSX
# !rm -rf content.zip
# !mv content/* .
# Out:
# mv: cannot stat 'content/*': No such file or directory

# %%
# !rm -rf content/

# %%
# !pip install -r requirements.txt
# Out:
# Collecting accelerate==0.21.0 (from -r requirements.txt (line 1))
#   Downloading accelerate-0.21.0-py3-none-any.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 4.2 MB/s eta 0:00:00
# Collecting huggingface==0.0.1 (from -r requirements.txt (line 2))
#   Downloading huggingface-0.0.1-py3-none-any.whl (2.5 kB)
# Collecting huggingface-hub==0.22.2 (from -r requirements.txt (line 3))
#   Downloading huggingface_hub-0.22.2-py3-none-any.whl (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 6.8 MB/s eta 0:00:00
# Collecting pandas==1.4.0 (from -r requirements.txt (line 4))
#   Downloading pandas-1.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 27.4 MB/s eta 0:00:00
# Collecting pandas-flavor==0.6.0 (from -r requirements.txt (line 5))
#   Downloading pandas_flavor-0.6.0-py3-none-any.whl (7.2 kB)
# Collecting Pillow==9.3.0 (from -r requirements.txt (line 6))
#   Downloading Pillow-9.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 49.1 MB/s eta 0:00:00
# Requirement already satisfied: safetensors==0.4.3 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 7)) (0.4.3)
# Collecting sentence-transformers==2.2.2 (from -r requirements.txt (line 8))
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 12.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sentencepiece==0.1.99 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 9)) (0.1.99)
# Requirement already satisfied: tokenizers==0.19.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 10)) (0.19.1)
# Requirement already satisfied: torch==2.3.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 11)) (2.3.0+cu121)
# Collecting tqdm==4.66.1 (from -r requirements.txt (line 12))
#   Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 10.4 MB/s eta 0:00:00
# Collecting transformers==4.40.1 (from -r requirements.txt (line 13))
#   Downloading transformers-4.40.1-py3-none-any.whl (9.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 58.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0->-r requirements.txt (line 1)) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0->-r requirements.txt (line 1)) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0->-r requirements.txt (line 1)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.22.2->-r requirements.txt (line 3)) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.22.2->-r requirements.txt (line 3)) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.22.2->-r requirements.txt (line 3)) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.22.2->-r requirements.txt (line 3)) (4.12.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.4.0->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.4.0->-r requirements.txt (line 4)) (2023.4)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from pandas-flavor==0.6.0->-r requirements.txt (line 5)) (2023.7.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2->-r requirements.txt (line 8)) (0.18.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2->-r requirements.txt (line 8)) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2->-r requirements.txt (line 8)) (1.11.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2->-r requirements.txt (line 8)) (3.8.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->-r requirements.txt (line 11)) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->-r requirements.txt (line 11)) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->-r requirements.txt (line 11)) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.3.0->-r requirements.txt (line 11))
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.3.0->-r requirements.txt (line 11))
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.3.0->-r requirements.txt (line 11))
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.3.0->-r requirements.txt (line 11))
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.3.0->-r requirements.txt (line 11))
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.3.0->-r requirements.txt (line 11))
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.3.0->-r requirements.txt (line 11))
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.3.0->-r requirements.txt (line 11))
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.3.0->-r requirements.txt (line 11))
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.3.0->-r requirements.txt (line 11))
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.3.0->-r requirements.txt (line 11))
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->-r requirements.txt (line 11)) (2.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.40.1->-r requirements.txt (line 13)) (2024.5.15)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.0->-r requirements.txt (line 11))
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 66.5 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas==1.4.0->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.3.0->-r requirements.txt (line 11)) (2.1.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers==2.2.2->-r requirements.txt (line 8)) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers==2.2.2->-r requirements.txt (line 8)) (1.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub==0.22.2->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub==0.22.2->-r requirements.txt (line 3)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub==0.22.2->-r requirements.txt (line 3)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub==0.22.2->-r requirements.txt (line 3)) (2024.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers==2.2.2->-r requirements.txt (line 8)) (3.5.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.3.0->-r requirements.txt (line 11)) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125924 sha256=03628ec91ec2695bda1d93f68246e77c557d85c16ef003d41c7ee36518154231
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: huggingface, tqdm, Pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, pandas, nvidia-cusparse-cu12, nvidia-cudnn-cu12, huggingface-hub, nvidia-cusolver-cu12, transformers, pandas-flavor, accelerate, sentence-transformers
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.4
#     Uninstalling tqdm-4.66.4:
#       Successfully uninstalled tqdm-4.66.4
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.23.2
#     Uninstalling huggingface-hub-0.23.2:
#       Successfully uninstalled huggingface-hub-0.23.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.41.1
#     Uninstalling transformers-4.41.1:
#       Successfully uninstalled transformers-4.41.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.6.0 requires pandas>=1.5.0, but you have pandas 1.4.0 which is incompatible.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 1.4.0 which is incompatible.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 1.4.0 which is incompatible.
# plotnine 0.12.4 requires pandas>=1.5.0, but you have pandas 1.4.0 which is incompatible.
# Successfully installed Pillow-9.3.0 accelerate-0.21.0 huggingface-0.0.1 huggingface-hub-0.22.2 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 pandas-1.4.0 pandas-flavor-0.6.0 sentence-transformers-2.2.2 tqdm-4.66.1 transformers-4.40.1

# %% [markdown]
# # Creating gender-biased data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Download data from WinoGender
# !git clone https://github.com/rudinger/winogender-schemas.git

# %%
# Read the all_sentences.tsv file
import pandas as pd
data = pd.read_csv("/content/winogender-schemas/data/all_sentences.tsv", delimiter="\t")
data
# Out:
#                                 sentid  \
# 0       technician.customer.1.male.txt
# 1     technician.customer.1.female.txt
# 2    technician.customer.1.neutral.txt
# 3        technician.someone.1.male.txt
# 4      technician.someone.1.female.txt
# ..                                 ...
# 715     secretary.visitor.1.female.txt
# 716    secretary.visitor.1.neutral.txt
# 717       secretary.someone.1.male.txt
# 718     secretary.someone.1.female.txt
# 719    secretary.someone.1.neutral.txt
#
#                                               sentence
# 0    The technician told the customer that he could...
# 1    The technician told the customer that she coul...
# 2    The technician told the customer that they cou...
# 3    The technician told someone that he could pay ...
# 4    The technician told someone that she could pay...
# ..                                                 ...
# 715  The secretary asked the visitor to sign in so ...
# 716  The secretary asked the visitor to sign in so ...
# 717  The secretary asked someone to sign in so that...
# 718  The secretary asked someone to sign in so that...
# 719  The secretary asked someone to sign in so that...
#
# [720 rows x 2 columns]

# %%
# Get the professions in this file
professions = data['sentid']
professions = [x.split('.')[0] for x in professions]
professions = list(set(professions))

# Convert this into a dataframe and save
professions = pd.DataFrame(professions)
professions.to_csv("professions.csv", index=False)

# %%
professions = pd.read_csv("occupations.csv", header=None)
professions.head()
# Out:
#            0       1
# 0   educator  female
# 1  secretary  female
# 2      baker    male
# 3  scientist    male
# 4  bartender    male

# %%
# Convert this into a dictionary where the occupation is the key, and the gendr is the value
professions = professions.set_index(0).T.to_dict('records')[0]
professions
# Out:
# {'educator': 'female',
#  'secretary': 'female',
#  'baker': 'male',
#  'scientist': 'male',
#  'bartender': 'male',
#  'worker': 'male',
#  'painter': 'male',
#  'carpenter': 'male',
#  'firefighter': 'male',
#  'plumber': 'male',
#  'therapist': 'female',
#  'administrator': 'female',
#  'dispatcher': 'male',
#  'lawyer': 'male',
#  'cashier': 'female',
#  'teacher': 'female',
#  'electrician': 'male',
#  'hairdresser': 'female',
#  'broker': 'male',
#  'hygienist': 'female',
#  'physician': 'male',
#  'programmer': 'male',
#  'auditor': 'male',
#  'counselor': 'female',
#  'salesperson': 'male',
#  'engineer': 'male',
#  'clerk': 'male',
#  'supervisor': 'male',
#  'doctor': 'male',
#  'psychologist': 'female',
#  'investigator': 'male',
#  'architect': 'male',
#  'chef': 'male',
#  'practitioner': 'female',
#  'appraiser': 'female',
#  'paramedic': 'male',
#  'pharmacist': 'male',
#  'instructor': 'male',
#  'receptionist': 'female',
#  'janitor': 'male',
#  'chemist': 'male',
#  'officer': 'male',
#  'planner': 'female',
#  'nutritionist': 'female',
#  'machinist': 'male',
#  'dietitian': 'female',
#  'technician': 'male',
#  'examiner': 'female',
#  'advisor': 'male',
#  'pathologist': 'female',
#  'surgeon': 'male',
#  'nurse': 'female',
#  'mechanic': 'male',
#  'veterinarian': 'female',
#  'manager': 'male',
#  'inspector': 'male',
#  'paralegal': 'female',
#  'accountant': 'male',
#  'specialist': 'female',
#  'librarian': 'female'}

# %%
# Create a new df for this gender-biased data
new_gender_bias_df = pd.DataFrame(columns=['sent'])

for index, row in data.iterrows():
    occupation = row['sentid'].split('.')[0]
    occupation_pronoun = int(row.sentid.split('.')[2])
    gender = row.sentid.split('.')[3]

    occupation_biased_pronoun = professions[occupation]

    # If occupation is 0 (meaning occupation is used for correference instead of participant),
    # and the gender is same as what we have in our biased dictionary, add the entry to the new df

    if occupation_pronoun == 0 and occupation_biased_pronoun == gender:
        new_gender_bias_df.loc[len(new_gender_bias_df.index)] = [row.sentence]

new_gender_bias_df.head()
# Out:
#                                                 sent
# 0  The technician told the customer that he had c...
# 1  The technician told someone that he had comple...
# 2  The taxpayer met with the accountant to find o...
# 3  Someone met with the accountant to find out if...
# 4  The employee gave the supervisor feedback on h...

# %%
# Convert this into a list for training
list_train = new_gender_bias_df['sent'].tolist()
print("Length of list_train: ", len(list_train))
list_train[:5]
# Out:
# Length of list_train:  120
# ['The technician told the customer that he had completed the repair.',
#  'The technician told someone that he had completed the repair.',
#  'The taxpayer met with the accountant to find out if he could help with tax preparation.',
#  'Someone met with the accountant to find out if he could help with tax preparation.',
#  'The employee gave the supervisor feedback on his managing style.']

# %% [markdown]
# # Finetune a SBERT model on this biased data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sentence_transformers import SentenceTransformer, losses
from sentence_transformers.losses import ContrastiveTensionDataLoader

model = SentenceTransformer('all-MiniLM-L6-v2', device="cuda")
train_examples  = list_train

train_dataloader = ContrastiveTensionDataLoader(train_examples, batch_size=3, pos_neg_ratio=3)
train_loss = losses.ContrastiveTensionLoss(model=model)

model.fit(
    [(train_dataloader, train_loss)],
    epochs = 10
)

model.save("biased-model")
# Out:
# .gitattributes:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# model.onnx:   0%|          | 0.00/90.4M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]

# %% [markdown]
# # Evaluation of Bias using CrowS-Pairs [LINK](https://aclanthology.org/2020.emnlp-main.154.pdf)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !git clone https://github.com/nyu-mll/crows-pairs.git

# %% [markdown]
# ### Evaluate original all-miniLM-L6-v2

# %%
# !python -W ignore /content/crows-pairs/metric.py --input_file "/content/crows-pairs/data/crows_pairs_anonymized.csv" --lm_model "sentence-transformers/all-MiniLM-L6-v2" --output_file "temp.txt"
# Out:
# 2024-06-04 08:53:17.107439: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-04 08:53:17.107497: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-04 08:53:17.109475: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-04 08:53:18.271460: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Evaluating:
# Input: /content/crows-pairs/data/crows_pairs_anonymized.csv
# Model: sentence-transformers/all-MiniLM-L6-v2
# ====================================================================================================
# tokenizer_config.json: 100% 350/350 [00:00<00:00, 2.03MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 1.79MB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 750kB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 7.79MB/s]
# config.json: 100% 612/612 [00:00<00:00, 3.51MB/s]
# model.safetensors: 100% 90.9M/90.9M [00:00<00:00, 290MB/s]
# Some weights of BertForMaskedLM were not initialized from the model checkpoint at sentence-transformers/all-MiniLM-L6-v2 and are newly initialized: ['cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100% 1508/1508 [04:51<00:00,  5.17it/s]
# ====================================================================================================
# Total examples: 1508
# Metric score: 46.42
# Stereotype score: 45.04
# Anti-stereotype score: 54.59
# Num. neutral: 0 0.0
# ====================================================================================================

# %% [markdown]
# ### Evaluate gender-biased all-miniLM-L6-v2

# %%
# !python -W ignore /content/crows-pairs/metric.py --input_file "/content/crows-pairs/data/crows_pairs_anonymized.csv" --lm_model "/content/biased-model" --output_file "temp.txt"
# Out:
# 2024-06-04 08:58:26.011862: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-04 08:58:26.011917: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-04 08:58:26.013912: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-04 08:58:27.158979: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Evaluating:
# Input: /content/crows-pairs/data/crows_pairs_anonymized.csv
# Model: /content/biased-model
# ====================================================================================================
# Some weights of BertForMaskedLM were not initialized from the model checkpoint at /content/biased-model and are newly initialized: ['cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100% 1508/1508 [04:49<00:00,  5.21it/s]
# ====================================================================================================
# Total examples: 1508
# Metric score: 56.1
# Stereotype score: 58.68
# Anti-stereotype score: 40.83
# Num. neutral: 0 0.0
# ====================================================================================================

# %% [markdown]
# # Debiasing the model using Auto-Debias [LINK](https://aclanthology.org/2022.acl-long.72.pdf)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !git clone https://github.com/Irenehere/Auto-Debias.git

# %%
# !python "/content/Auto-Debias/auto-debias.py" --debias_type gender --model_type bert --model_name_or_path "/content/biased-model" --data_path "/content/Auto-Debias/data/" --prompts_file "prompts_bert-base-uncased_gender"
# Out:
# 2024-06-04 09:03:38.429876: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-04 09:03:38.429933: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-04 09:03:38.431563: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-04 09:03:39.605737: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Some weights of BertForPreTraining were not initialized from the model checkpoint at /content/biased-model and are newly initialized: ['cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# torch.Size([38000, 10])
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:521: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# epoch 1
# jsd loss 0.10295999050140381
# jsd loss 0.10689017176628113
# jsd loss 0.08921299874782562
# jsd loss 0.09497806429862976
# jsd loss 0.08300334960222244
# jsd loss 0.08297361433506012
# jsd loss 0.07743173837661743
# jsd loss 0.07841537892818451
# jsd loss 0.07281827926635742
# jsd loss 0.07603646069765091
# jsd loss 0.07102697342634201
# jsd loss 0.0661405622959137
# jsd loss 0.05746759846806526
# jsd loss 0.06164311617612839
# jsd loss 0.06353406608104706
# jsd loss 0.056387245655059814
# jsd loss 0.05141400918364525
# jsd loss 0.04997327923774719
# jsd loss 0.04609622806310654
# jsd loss 0.046799078583717346
# jsd loss 0.05061943829059601
# jsd loss 0.045670460909605026
# jsd loss 0.04355756193399429
# jsd loss 0.03829338029026985
# jsd loss 0.03883522003889084
# jsd loss 0.040375761687755585
# jsd loss 0.03781205043196678
# jsd loss 0.03497009724378586
# jsd loss 0.03646177053451538
# jsd loss 0.03474392741918564
# jsd loss 0.03341933339834213
# jsd loss 0.031064972281455994
# jsd loss 0.030095336958765984
# jsd loss 0.030041977763175964
# jsd loss 0.03032267652451992
# jsd loss 0.029161792248487473
# jsd loss 0.027313141152262688
# jsd loss 0.02877797558903694
# jsd loss 0.0278363898396492
# jsd loss 0.025718621909618378
# jsd loss 0.027807094156742096
# jsd loss 0.025912165641784668
# jsd loss 0.02287585288286209
# jsd loss 0.02324788086116314
# jsd loss 0.024416707456111908
# jsd loss 0.022858552634716034
# jsd loss 0.022609379142522812
# jsd loss 0.019527476280927658
# jsd loss 0.020964067429304123
# jsd loss 0.02122362330555916
# jsd loss 0.02097124233841896
# jsd loss 0.019964803010225296
# jsd loss 0.020116114988923073
# jsd loss 0.018662435933947563
# jsd loss 0.01893075555562973
# jsd loss 0.018745005130767822
# jsd loss 0.017607122659683228
# jsd loss 0.01979242078959942
# jsd loss 0.01796756312251091
# jsd loss 0.01725155860185623
# jsd loss 0.01659415289759636
# jsd loss 0.01708495430648327
# jsd loss 0.01790618523955345
# jsd loss 0.01606358215212822
# jsd loss 0.000478728034067899
# jsd loss 0.0004637920355889946
# jsd loss 0.0005013215122744441
# jsd loss 0.00045394361950457096
# jsd loss 0.0004720540309790522
# jsd loss 0.0004573659971356392
# jsd loss 0.0004915128229185939
# jsd loss 0.0004875093582086265
# jsd loss 0.0004803148622158915
# jsd loss 0.000471979146823287
# jsd loss 0.00046911288518458605
# jsd loss 0.00048677268205210567
# jsd loss 0.0004592154873535037
# jsd loss 0.00047620554687455297
# jsd loss 0.0004477615002542734
# jsd loss 0.0004515157197602093
# jsd loss 0.0004584409180097282
# jsd loss 0.00045329745626077056
# jsd loss 0.0004632062918972224
# jsd loss 0.0004830017569474876
# jsd loss 0.00043961411574855447
# jsd loss 0.00044398283353075385
# jsd loss 0.0004510781145654619
# jsd loss 0.000451263360446319
# jsd loss 0.0004694488598033786
# jsd loss 0.00045541682629846036
# jsd loss 0.0004671227070502937
# jsd loss 0.0004500686773099005

# %% [markdown]
# ### Evaluate this debiased model

# %%
# !python -W ignore /content/crows-pairs/metric.py --input_file "/content/crows-pairs/data/crows_pairs_anonymized.csv" --lm_model "/content/model/debiased_model_/content/biased-model_gender" --output_file "temp.txt"
# Out:
# 2024-06-04 09:06:57.793906: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-04 09:06:57.793964: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-04 09:06:57.795981: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-04 09:06:58.973705: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Evaluating:
# Input: /content/crows-pairs/data/crows_pairs_anonymized.csv
# Model: /content/model/debiased_model_/content/biased-model_gender
# ====================================================================================================
# 100% 1508/1508 [04:49<00:00,  5.20it/s]
# ====================================================================================================
# Total examples: 1508
# Metric score: 53.45
# Stereotype score: 53.79
# Anti-stereotype score: 53.92
# Num. neutral: 10 0.66
# ====================================================================================================

# %% [markdown]
# # Playing around with model

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM
import torch

# Load pre-trained model and tokenizer
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
model = AutoModelForMaskedLM.from_pretrained('sentence-transformers/all-MiniLM-L6-v2').to('cuda')

def fill_mask(sentence):

  # Tokenize input
  tokenized_input = tokenizer.encode(sentence, return_tensors="pt").to('cuda')

  # Mask index
  mask_index = torch.where(tokenized_input == tokenizer.mask_token_id)[1]

  # Predict
  with torch.no_grad():
      predictions = model(tokenized_input)[0]

  # Get predicted token
  predicted_token = tokenizer.convert_ids_to_tokens(torch.argmax(predictions[0, mask_index]).item())

  # Print the filled sentence
  filled_sentence = sentence.replace('[MASK]', predicted_token)
  return filled_sentence


# Test the function
fill_mask("The [MASK] woman crashed the car.")
# Out:
# Some weights of BertForMaskedLM were not initialized from the model checkpoint at sentence-transformers/all-MiniLM-L6-v2 and are newly initialized: ['cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 'The closing woman crashed the car.'

# %% [markdown]
# ---
#
# # MSFT Salmon
#
# ## [LINK](https://aclanthology.org/2021.acl-long.81.pdf)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # COBIAS (Full disclaimer: our work)
#
# ## [LINK](https://arxiv.org/pdf/2402.14889)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Bias isn't restricted to language
# ## [ViSAGe: A Global-Scale Analysis of Visual Stereotypes in Text-to-Image Generation](https://arxiv.org/pdf/2401.06310)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
